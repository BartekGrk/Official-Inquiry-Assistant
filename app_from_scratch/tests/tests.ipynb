# %%
import fitz
import re

GLYPH_MAP = str.maketrans({
    "Ê": "ś",
    "´": "ę",
    "∏": "ł",
    "à": "ą",
    "˝": "ż",
    "ƒ": "ń",
    "ç": "ć",
    "ê": "ź",
})
out = text.translate(GLYPH_MAP)

# %%
path = "..\data\docs\D20011198.pdf"
doc  = fitz.open(path)
text_list = []
page_num = 0
for page in doc:
    page_num += 1
    text_list.append({"page": page_num, "text": page.get_text("text")})

# %%
text = text_list[0]["text"]
